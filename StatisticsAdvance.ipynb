# %%
"""Statistics Advance Assignment"""

# %%
"""
Q1) Define the z-statistic and explain its relationship to the standard normal distribution. How is the z-statistic used in hypothesis 
    testing?
Answer-
    The z-statistic, also known as the z-score, is a measure that describes the position of a data point relative to the mean of a dataset,
    expressed in terms of standard deviations. 

    The z-statistic for a sample mean is given by the formula:
    z = (sample mean) - (population mean) / standard error of the mean 
    where, standard error of the mean = population standard deviation divided by the square root of the sample size.

    While dealing with a single data point, the z-score would be: 
    z = (individual data point x) - mean of the population / standard deviation of the population.

    Relationship to the Standard Normal Distribution:
    The z-statistic is directly related to the standard normal distribution (also known as the Z-distribution), which has:
    mean of 0 and standard deviation of 1.
    A z-statistic indicates how many standard deviations a particular value is from the mean. Positive z-values indicate values above the mean,
    and negative z-values indicate values below the mean. The standard normal distribution is symmetrical, and the area under the curve 
    represents probabilities.

    Use in Hypothesis Testing:
    The z-statistic is a key tool in hypothesis testing which helps determine whether the observed data differs significantly from the null
    hypothesis.
    Steps:
    1. State the hypotheses:
       * Null hypothesis (H₀): Assumes no effect or no difference.
       * Alternative hypothesis (H₁): Assumes there is an effect or difference.
    
    2. Compute the z-statistic: Based on the sample data, calculate the z-statistic to measure how far the sample mean is from the population
       mean, assuming the null hypothesis is true.

    3. Find the critical value: This is determined by the significance level (𝛼), which typically is 0.05 for a 95% confidence level.
       Critical z-values correspond to the probability cutoffs (e.g., ±1.96 for a two-tailed test at α=0.05).

    4. Compare the z-statistic to the critical value:
       * If the absolute value of the z-statistic is greater than the critical value, you reject the null hypothesis, indicating that the 
         sample provides enough evidence to conclude a significant difference.
       * If the z-statistic falls within the critical region, you fail to reject the null hypothesis, indicating insufficient evidence of a 
         significant difference.
"""

# %%
"""
Q2) What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?
Answer- 
    A p-value (probability value) is a measure in hypothesis testing that helps determine the strength of evidence against the null hypothesis.
    It represents the probability of obtaining the observed data assuming the null hypothesis is true.

    How the p-value is used in hypothesis testing:
    1. Formulate hypotheses:
       * Null hypothesis (H₀): Assumes no effect, difference, or relationship exists.
       * Alternative hypothesis (H₁): Assumes there is an effect, difference, or relationship.
    
    2. Conduct the test: Based on the observed data, calculate a test statistic (e.g., z-statistic, t-statistic) and use it to find the 
       p-value.

    3. Compare the p-value to the significance level (α): The significance level (α) is a threshold (commonly 0.05 or 0.01) that defines how
       much evidence is needed to reject the null hypothesis.
       If the p-value is less than or equal to the significance level, reject the null hypothesis.
       If the p-value is greater than fail to significance level, reject the null hypothesis.

    Interpretation of a small p-value (e.g., 0.01):
    A p-value of 0.01 means there is a 1% chance that the observed result happened by random chance, assuming the null hypothesis is true.
    A very small p-value (like 0.01 or smaller) means the observed result is very unlikely to be due to chance, so you have strong evidence 
    against the null hypothesis.
"""

# %%
"""
Q3) Compare and contrast the binomial and Bernoulli distributions.
Answer-
    The Bernoulli and Binomial distributions are both discrete probability distributions related to binary outcomes, such as success/failure 
    or yes/no events.

    1) Definition -
       The Bernoulli distribution : Describes a single trial with two possible outcomes, like flipping a coin once (heads = 1, tails = 0). 
       It has only one parameter,p, which is the probability of success.
       The Binomial distribution : Describes the number of successes in multiple trials (like flipping a coin 10 times and counting the heads). 
       It has two parameters: n (number of trials) and p (probability of success in each trial).

    2) Key Characteristics -
       * Trials- 
       Bernoulli: Involves a single trial.
       Binomial: Involves multiple independent trials (n trials).

       * Range of Possible Values:
        Bernoulli: The random variable X can only take two values: 0 or 1.
        Binomial: The random variable X can take integer values from 0 to n, representing the count of successes.

    3) Mean and Variance -
       * Bernoulli Distribution:
       Mean: μ=p
       Variance: 𝜎 ** 2 = p(1-p)

       * Bernoulli Distribution:
       Mean: μ = np
       Variance: 𝜎 ** 2 = np(1-p)

    4) Use case -
       * Bernoulli Distribution - Single binary outcome
       * Binomial Distribution - Count of successes over n trials.
"""

# %%
"""
Q4) Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli distribution?
Answer-
    The binomial distribution is used under the following conditions:

    1. Fixed Number of Trials: There is a specific, finite number of trials (denoted as n).
    2. Two Possible Outcomes: Each trial has only two possible outcomes, commonly labeled as "success" and "failure."
    3. Constant Probability: The probability of success (denoted as p) is the same for each trial.
    4. Independent Trials: The outcome of each trial is independent of the others.

    Relation to the Bernoulli Distribution
    The Bernoulli distribution is a special case of the binomial distribution where there's only one trial (n=1). A Bernoulli trial has only 
    two possible outcomes with probabilities p (success) and 1-p (failure). If multiple Bernoulli trials are conducted under identical 
    conditions, the binomial distribution then models the total number of successes across those trials.

    So, the binomial distribution can be thought of as the sum of several independent Bernoulli trials with the same probability of success.
"""

# %%
"""
Q5) What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution?
Answer-
    The Poisson distribution models the number of times an event occurs within a fixed interval of time or space, under certain conditions.
    Here are its key properties and when it's appropriate to use it:
    1. Discrete Distribution: It describes the count of events in a fixed interval, so it's only concerned with whole numbers (0, 1, 2, etc.).
    2. Single Parameter (λ): The distribution is defined by the average rate (λ) of occurrences in the interval, which is both the mean 
       and variance of the distribution.
    3. Mean and Variance: The mean and variance of a Poisson distribution are both equal to λ, the average rate.
    4. Independent Events: The occurrences of events are independent; one event happening doesn't influence the probability of another event.
    5. No Upper Limit: There's theoretically no maximum number of occurrences, although higher counts become less likely as they deviate from λ.

  
    The Poisson distribution is appropriate to use when:

    1. Events Occur Randomly and independently over time or space.
    2. Fixed Interval: You're counting events over a set interval (e.g., per minute, per square kilometer).
    3. Known Average Rate: You have a known, constant average rate of occurrences (λ) within that interval.
    4. Rare Events in Large Samples: It's useful when events are rare in relation to a large number of possible occurrences 
       (e.g., defective items in a large production batch or customer arrivals at a service point per hour).
"""

# %%
"""
Q6) Define the terms "probability distribution" and "probability density function" (PDF). How does a PDF differ from a probability mass 
    function (PMF)?
Answer-
    Probability Distribution - A probability distribution describes how the values of a random variable are spread out. It assigns 
    probabilities to each possible outcome for that random variable and provides a complete picture of all possible outcomes and their 
    associated probabilities. Probability distributions can be either:
    1. Discrete (for countable outcomes, like the number of heads in coin flips).
    2. Continuous (for uncountable outcomes, like heights or weights).    

    Probability Density Function (PDF) - A Probability Density Function (PDF) applies to continuous random variables. It represents the
    likelihood (density) that a variable will take on a certain value within a continuous range.

    Probability Mass Function (PMF) -A Probability Mass Function (PMF) is used for discrete random variables and gives the probability of 
    each specific, countable outcome. For example, the PMF of a discrete variable X might tell us P(X=x), the probability of X equaling x.

    Differences Between PDF and PMF
    1. Type of Variable:
       PDF: Used for continuous random variables.
       PMF: Used for discrete random variables.
    2. Interpretation:
       PDF: Represents probability density (not direct probabilities). To get probabilities, integrate over intervals.
       PMF: Directly gives the probability of specific outcomes (e.g., P(X=x)).
    3. Values:
       PDF: Can take values greater than 1; however, the total area under the curve equals 1.
       PMF: Values always range between 0 and 1, and the sum of all probabilities across possible outcomes equals 1.    
"""

# %%
"""
Q7) Explain the Central Limit Theorem (CLT) with example.
Answer-
    The Central Limit Theorem (CLT) says that if you take a large enough sample size from any population (no matter how it's shaped), the 
    average of those samples will form a normal (bell-shaped) distribution.
    Key Points:
    1. Shape Doesn't Matter: The population could be skewed, but the sample means will still look normal.
    2. Sample Size: A larger sample size (usually n ≥ 30) makes this work better.
    3. Mean & Standard Error: The average of sample means will be close to the population mean, and the spread (standard error) depends on 
       the population standard deviation divided by the square root of the sample size.

    Example of the Central Limit Theorem - 
    Imagine we're interested in the average time people spend on a particular website each day. We don't know the actual distribution of 
    all user times; it might be heavily skewed since some people spend only a few seconds while others might spend hours.

    1. Population: Let's assume the average time spent is 20 minutes with a standard deviation of 10 minutes.
    2. Sampling: We take a sample of 50 people from this population and record the average time each person spent on the site.
    3. Distribution of Sample Means: If we repeat this process (taking new samples of 50 people and calculating each sample's mean time 
       spent), we get a distribution of sample means.
    4. Result of the CLT: According to the CLT, the distribution of these sample means will approximate a normal distribution with:
       * Mean μ=20 minutes (same as the population mean), 
       * Standard Error σ / square root of n = 10 / square root of 50 ≈ 1.41 minutes.
    
    So, even if the distribution of individual times is not normal, the distribution of the sample means will be approximately normal if the
    sample size is large (in this case, 50).
"""

# %%
"""
Q8) Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be applied instead?
Answer-
    Z-scores and t-scores are both used in statistics to measure how far a sample mean or individual data point is from the population mean 
    in terms of standard deviations, but they are used in different situations:

    Z-Score -
    Definition: A z-score (or standard score) measures how many standard deviations a data point is from the mean.
    Formula: Z= (X - μ) / σ
    where X is the data point, μ is the population mean, and σ is the population standard deviation.
    
    Use a z-score when:
    1. The sample size is large (typically n>30).
    2. You know the population standard deviation (σ).
    3. The population follows a normal distribution or the sample size is large enough for the Central Limit Theorem to apply.

    T-Score
    Definition: A t-score is similar to a z-score but accounts for the uncertainty introduced by using a sample instead of the entire 
    population.
    Formula: T = (X -X bar) / (s / square root of n)
    where X is the sample mean, X bar is the sample mean, s is the sample standard deviation, and n is the sample size.
    
    Use a t-score when:
    1. The sample size is small (typically n<30).
    2. You don't know the population standard deviation and have to estimate it with the sample standard deviation.
    3. The data is approximately normally distributed (especially important for smaller sample sizes).

    Key Differences
    1. Sample Size: Z-scores are used for larger samples, t-scores for smaller samples.
    2. Population vs. Sample Standard Deviation: Z-scores require the population standard deviation, while t-scores use the sample standard
       deviation as an estimate.
    3. Distribution: Z-scores follow the standard normal distribution; t-scores follow the t-distribution, which is broader and has heavier 
       tails (accounts for more variability) when the sample size is small.
"""

# %%
"""
Q9) Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample size of 25, calculate the z-score and
    p-value. Based on a significance level of 0.05, do you reject or fail to reject the null hypothesis?
    Task: Write Python code to calculate the z-score and p-value for the given data.
    Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.
"""
from scipy.stats import norm

sample_mean = 105
population_mean = 100
std_dev = 15
sample_size = 25
alpha = 0.05  

standard_error = std_dev / (sample_size ** 0.5)

z_score = (sample_mean - population_mean) / standard_error

p_value = 2 * (1 - norm.cdf(abs(z_score)))  # two-tailed p-value

# Determine the decision based on the p-value
decision = "Reject the null hypothesis" if p_value < alpha else "Fail to reject the null hypothesis"

z_score, p_value, decision
# Out:
# (1.6666666666666667,
#  np.float64(0.09558070454562939),
#  'Fail to reject the null hypothesis')

# %%
"""
Q10) Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python. Generate 1,000 samples and plot the
     distribution. What is the expected mean and variance? 
     Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.
     Objective: Understand the properties of a binomial distribution and verify them through simulation.
Answer-
"""
import numpy as np
import matplotlib.pyplot as plt

n_trials = 10         
p_success = 0.6       
n_samples = 1000      

# Simulate binomial distribution
data = np.random.binomial(n=n_trials, p=p_success, size=n_samples)

# Calculate expected mean and variance
expected_mean = n_trials * p_success
expected_variance = n_trials * p_success * (1 - p_success)

# Plot the distribution
plt.figure(figsize=(10, 6))
plt.hist(data, bins=range(n_trials + 2), align='left', color='skyblue', edgecolor='black', rwidth=0.8)
plt.title('Binomial Distribution (n=10, p=0.6) - 1,000 Samples')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.xticks(range(n_trials + 1))
plt.show()

# Output expected mean and variance
expected_mean, expected_variance
# Out:
# (6.0, 2.4000000000000004)
